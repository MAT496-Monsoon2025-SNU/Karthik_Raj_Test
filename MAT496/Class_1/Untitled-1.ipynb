# %%
pip install dotenv
# Out:
# Requirement already satisfied: dotenv in c:\users\hp\anaconda3\envs\langchain\lib\site-packages (0.9.9)
# Requirement already satisfied: python-dotenv in c:\users\hp\anaconda3\envs\langchain\lib\site-packages (from dotenv) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# False

# %%
# !pip install -qU "langchain[groq]"

# %%
pip install langchain
# Out:
# Collecting langchain
#   Downloading langchain-0.3.27-py3-none-any.whl.metadata (7.8 kB)
# Collecting langchain-core<1.0.0,>=0.3.72 (from langchain)
#   Downloading langchain_core-0.3.74-py3-none-any.whl.metadata (5.8 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.9 (from langchain)
#   Downloading langchain_text_splitters-0.3.9-py3-none-any.whl.metadata (1.9 kB)
# Collecting langsmith>=0.1.17 (from langchain)
#   Downloading langsmith-0.4.15-py3-none-any.whl.metadata (14 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Downloading pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading sqlalchemy-2.0.43-cp39-cp39-win_amd64.whl.metadata (9.8 kB)
# Collecting requests<3,>=2 (from langchain)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting PyYAML>=5.3 (from langchain)
#   Downloading PyYAML-6.0.2-cp39-cp39-win_amd64.whl.metadata (2.1 kB)
# Collecting async-timeout<5.0.0,>=4.0.0 (from langchain)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<1.0.0,>=0.3.72->langchain)
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<1.0.0,>=0.3.72->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\hp\anaconda3\envs\langchain\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in c:\users\hp\anaconda3\envs\langchain\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading pydantic_core-2.33.2-cp39-cp39-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3,>=2->langchain)
#   Downloading charset_normalizer-3.4.3-cp39-cp39-win_amd64.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2->langchain)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2->langchain)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2->langchain)
#   Downloading certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting greenlet>=1 (from SQLAlchemy<3,>=1.4->langchain)
#   Downloading greenlet-3.2.4-cp39-cp39-win_amd64.whl.metadata (4.2 kB)
# Collecting httpx<1,>=0.23.0 (from langsmith>=0.1.17->langchain)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson>=3.9.14 (from langsmith>=0.1.17->langchain)
#   Downloading orjson-3.11.2-cp39-cp39-win_amd64.whl.metadata (1.2 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith>=0.1.17->langchain)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard>=0.23.0 (from langsmith>=0.1.17->langchain)
#   Downloading zstandard-0.24.0-cp39-cp39-win_amd64.whl.metadata (3.2 kB)
# Collecting anyio (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain)
#   Downloading anyio-4.10.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting exceptiongroup>=1.0.2 (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain)
#   Downloading exceptiongroup-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting sniffio>=1.1 (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Downloading langchain-0.3.27-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    -------------------- ------------------- 0.5/1.0 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 3.2 MB/s eta 0:00:00
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading langchain_core-0.3.74-py3-none-any.whl (443 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langchain_text_splitters-0.3.9-py3-none-any.whl (33 kB)
# Downloading pydantic-2.11.7-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp39-cp39-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 5.6 MB/s eta 0:00:01
#    -------------------------------- ------- 1.6/2.0 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 4.2 MB/s eta 0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.3-cp39-cp39-win_amd64.whl (107 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading sqlalchemy-2.0.43-cp39-cp39-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    -------------- ------------------------- 0.8/2.1 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 4.0 MB/s eta 0:00:00
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading certifi-2025.8.3-py3-none-any.whl (161 kB)
# Downloading greenlet-3.2.4-cp39-cp39-win_amd64.whl (298 kB)
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading langsmith-0.4.15-py3-none-any.whl (375 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading orjson-3.11.2-cp39-cp39-win_amd64.whl (119 kB)
# Downloading PyYAML-6.0.2-cp39-cp39-win_amd64.whl (162 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Downloading zstandard-0.24.0-cp39-cp39-win_amd64.whl (505 kB)
# Downloading anyio-4.10.0-py3-none-any.whl (107 kB)
# Downloading exceptiongroup-1.3.0-py3-none-any.whl (16 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: zstandard, urllib3, typing-inspection, tenacity, sniffio, PyYAML, pydantic-core, orjson, jsonpointer, idna, h11, greenlet, exceptiongroup, charset_normalizer, certifi, async-timeout, annotated-types, SQLAlchemy, requests, pydantic, jsonpatch, httpcore, anyio, requests-toolbelt, httpx, langsmith, langchain-core, langchain-text-splitters, langchain
#
#    ----------------------------------------  0/29 [zstandard]
#    - --------------------------------------  1/29 [urllib3]
#    - --------------------------------------  1/29 [urllib3]
#    - --------------------------------------  1/29 [urllib3]
#    - --------------------------------------  1/29 [urllib3]
#    - --------------------------------------  1/29 [urllib3]
#    ---- -----------------------------------  3/29 [tenacity]
#    ---- -----------------------------------  3/29 [tenacity]
#    ----- ----------------------------------  4/29 [sniffio]
#    ------ ---------------------------------  5/29 [PyYAML]
#    ------ ---------------------------------  5/29 [PyYAML]
#    -------- -------------------------------  6/29 [pydantic-core]
#    --------- ------------------------------  7/29 [orjson]
#    ------------ ---------------------------  9/29 [idna]
#    ------------ ---------------------------  9/29 [idna]
#    ------------ ---------------------------  9/29 [idna]
#    ------------- -------------------------- 10/29 [h11]
#    ------------- -------------------------- 10/29 [h11]
#    --------------- ------------------------ 11/29 [greenlet]
#    --------------- ------------------------ 11/29 [greenlet]
#    --------------- ------------------------ 11/29 [greenlet]
#    --------------- ------------------------ 11/29 [greenlet]
#    ---------------- ----------------------- 12/29 [exceptiongroup]
#    ----------------- ---------------------- 13/29 [charset_normalizer]
#    ----------------- ---------------------- 13/29 [charset_normalizer]
#    ------------------- -------------------- 14/29 [certifi]
#    ---------------------- ----------------- 16/29 [annotated-types]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ----------------------- ---------------- 17/29 [SQLAlchemy]
#    ------------------------ --------------- 18/29 [requests]
#    ------------------------ --------------- 18/29 [requests]
#    -------------------------- ------------- 19/29 [pydantic]
#    -------------------------- ------------- 19/29 [pydantic]
#    -------------------------- ------------- 19/29 [pydantic]
#    -------------------------- ------------- 19/29 [pydantic]
#    -------------------------- ------------- 19/29 [pydantic]
#    -------------------------- ------------- 19/29 [pydantic]
#    -------------------------- ------------- 19/29 [pydantic]
#    -------------------------- ------------- 19/29 [pydantic]
#    -------------------------- ------------- 19/29 [pydantic]
#    -------------------------- ------------- 19/29 [pydantic]
#    -------------------------- ------------- 19/29 [pydantic]
#    -------------------------- ------------- 19/29 [pydantic]
#    -------------------------- ------------- 19/29 [pydantic]
#    -------------------------- ------------- 19/29 [pydantic]
#    ---------------------------- ----------- 21/29 [httpcore]
#    ---------------------------- ----------- 21/29 [httpcore]
#    ---------------------------- ----------- 21/29 [httpcore]
#    ---------------------------- ----------- 21/29 [httpcore]
#    ------------------------------ --------- 22/29 [anyio]
#    ------------------------------ --------- 22/29 [anyio]
#    ------------------------------ --------- 22/29 [anyio]
#    ------------------------------ --------- 22/29 [anyio]
#    ------------------------------ --------- 22/29 [anyio]
#    ------------------------------- -------- 23/29 [requests-toolbelt]
#    ------------------------------- -------- 23/29 [requests-toolbelt]
#    ------------------------------- -------- 23/29 [requests-toolbelt]
#    --------------------------------- ------ 24/29 [httpx]
#    --------------------------------- ------ 24/29 [httpx]
#    --------------------------------- ------ 24/29 [httpx]
#    --------------------------------- ------ 24/29 [httpx]
#    ---------------------------------- ----- 25/29 [langsmith]
#    ---------------------------------- ----- 25/29 [langsmith]
#    ---------------------------------- ----- 25/29 [langsmith]
#    ---------------------------------- ----- 25/29 [langsmith]
#    ---------------------------------- ----- 25/29 [langsmith]
#    ---------------------------------- ----- 25/29 [langsmith]
#    ---------------------------------- ----- 25/29 [langsmith]
#    ----------------------------------- ---- 26/29 [langchain-core]
#    ----------------------------------- ---- 26/29 [langchain-core]
#    ----------------------------------- ---- 26/29 [langchain-core]
#    ----------------------------------- ---- 26/29 [langchain-core]
#    ----------------------------------- ---- 26/29 [langchain-core]
#    ----------------------------------- ---- 26/29 [langchain-core]
#    ----------------------------------- ---- 26/29 [langchain-core]
#    ----------------------------------- ---- 26/29 [langchain-core]
#    ----------------------------------- ---- 26/29 [langchain-core]
#    ----------------------------------- ---- 26/29 [langchain-core]
#    ----------------------------------- ---- 26/29 [langchain-core]
#    ----------------------------------- ---- 26/29 [langchain-core]
#    ----------------------------------- ---- 26/29 [langchain-core]
#    ----------------------------------- ---- 26/29 [langchain-core]
#    ----------------------------------- ---- 26/29 [langchain-core]
#    ----------------------------------- ---- 26/29 [langchain-core]
#    ----------------------------------- ---- 26/29 [langchain-core]
#    ----------------------------------- ---- 26/29 [langchain-core]
#    ----------------------------------- ---- 26/29 [langchain-core]
#    ----------------------------------- ---- 26/29 [langchain-core]
#    ----------------------------------- ---- 26/29 [langchain-core]
#    ------------------------------------- -- 27/29 [langchain-text-splitters]
#    ------------------------------------- -- 27/29 [langchain-text-splitters]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    -------------------------------------- - 28/29 [langchain]
#    ---------------------------------------- 29/29 [langchain]
#
# Successfully installed PyYAML-6.0.2 SQLAlchemy-2.0.43 annotated-types-0.7.0 anyio-4.10.0 async-timeout-4.0.3 certifi-2025.8.3 charset_normalizer-3.4.3 exceptiongroup-1.3.0 greenlet-3.2.4 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.10 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.27 langchain-core-0.3.74 langchain-text-splitters-0.3.9 langsmith-0.4.15 orjson-3.11.2 pydantic-2.11.7 pydantic-core-2.33.2 requests-2.32.5 requests-toolbelt-1.0.0 sniffio-1.3.1 tenacity-9.1.2 typing-inspection-0.4.1 urllib3-2.5.0 zstandard-0.24.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("llama3-8b-8192", model_provider="groq")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 from langchain.chat_models import init_chat_model
# ----> 3 model = init_chat_model("llama3-8b-8192", model_provider="groq")
#
# File c:\Users\hp\anaconda3\envs\Langchain\lib\site-packages\langchain\chat_models\base.py:324, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     316     warnings.warn(
#     317         f"{config_prefix=} has been set but no fields are configurable. Set "
#     318         f"`configurable_fields=(...)` to specify the model params that are "
#     319         f"configurable.",
#     320         stacklevel=2,
#     321     )
#     323 if not configurable_fields:
# --> 324     return _init_chat_model_helper(
#     325         cast(str, model),
#     326         model_provider=model_provider,
#     327         **kwargs,
#     328     )
#     329 if model:
#     330     kwargs["model"] = model
#
# File c:\Users\hp\anaconda3\envs\Langchain\lib\site-packages\langchain\chat_models\base.py:418, in _init_chat_model_helper(model, model_provider, **kwargs)
#     416     return ChatHuggingFace(model_id=model, **kwargs)
#     417 if model_provider == "groq":
# --> 418     _check_pkg("langchain_groq")
#     419     from langchain_groq import ChatGroq
#     421     return ChatGroq(model=model, **kwargs)
#
# File c:\Users\hp\anaconda3\envs\Langchain\lib\site-packages\langchain\chat_models\base.py:543, in _check_pkg(pkg, pkg_kebab)
#     539 pkg_kebab = pkg_kebab if pkg_kebab is not None else pkg.replace("_", "-")
#     540 msg = (
#     541     f"Unable to import {pkg}. Please install with `pip install -U {pkg_kebab}`"
#     542 )
# --> 543 raise ImportError(msg)
#
# ImportError: Unable to import langchain_groq. Please install with `pip install -U langchain-groq`
